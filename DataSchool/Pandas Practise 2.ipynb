# %%
import pandas as pd

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic['Name'].sort_values()
# Out:
# 845                      Abbing, Mr. Anthony
# 746              Abbott, Mr. Rossmore Edward
# 279         Abbott, Mrs. Stanton (Rosa Hunt)
# 308                      Abelson, Mr. Samuel
# 874    Abelson, Mrs. Samuel (Hannah Wizosky)
#                        ...
# 286                  de Mulder, Mr. Theodore
# 282                de Pelsmaeker, Mr. Alfons
# 361                del Carlo, Mr. Sebastiano
# 153          van Billiard, Mr. Austin Blyler
# 868              van Melkebeke, Mr. Philemon
# Name: Name, Length: 891, dtype: object

# %%
titanic.sort_values(['Age','Name'],ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 507          508         1       1
# 593          594         0       3
# 140          141         0       3
# 598          599         0       3
# 168          169         0       1
#
#                                               Name     Sex   Age  SibSp  \
# 630           Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                            Svensson, Mr. Johan    male  74.0      0
# 96                       Goldschmidt, Mr. George B    male  71.0      0
# 493                        Artagaveytia, Mr. Ramon    male  71.0      0
# 116                           Connors, Mr. Patrick    male  70.5      0
# ..                                             ...     ...   ...    ...
# ...

# %%
titanic.Age.order()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29056/198539278.py in <module>
# ----> 1 titanic.Age.order()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'order'

# %%
titanic.sort('Age')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29056/1071513302.py in <module>
# ----> 1 titanic.sort('Age')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
booleans = []
for length in titanic.Fare:
    if length>=20:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
booleans[0:5]
# Out:
# [False, True, False, True, False]

# %%
len(booleans)
# Out:
# 891

# %%
titanic.shape
# Out:
# (891, 12)

# %%
is_long = pd.Series(booleans)

# %%
is_long.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
is_long = titanic.Fare>=20
is_long.head()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: Fare, dtype: bool

# %%
titanic[is_long]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic.Fare>=20]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
titanic[(titanic['Fare']>=20) | (titanic['Sex']=='F')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 7              8         0       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic.Embarked.isin(['S','Q'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv",usecols=[0,4])

# %%
titanic.head()
# Out:
#    PassengerId     Sex
# 0            1    male
# 1            2  female
# 2            3  female
# 3            4  female
# 4            5    male

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv",nrows=3)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
for c in titanic.Cabin:
    print(c)
# Out:
# nan
# C85
# nan
# C123
# nan
# nan
# E46
# nan
# nan
# nan
# G6
# C103
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# D56
# nan
# A6
# nan
# nan
# nan
# C23 C25 C27
# nan
# nan
# nan
# B78
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# D33
# nan
# B30
# C52
# nan
# nan
# nan
# nan
# nan
# B28
# C83
# nan
# nan
# nan
# F33
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# F G73
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C23 C25 C27
# nan
# nan
# nan
# E31
# nan
# nan
# nan
# A5
# D10 D12
# nan
# nan
# nan
# nan
# D26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C110
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# B58 B60
# nan
# nan
# nan
# nan
# E101
# D26
# nan
# nan
# nan
# F E69
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# D47
# C123
# nan
# B86
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# F2
# nan
# nan
# C2
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
for index,row in titanic.iterrows():
    print(index,row.Ticket,row.Cabin)
# Out:
# 0 A/5 21171 nan
# 1 PC 17599 C85
# 2 STON/O2. 3101282 nan
# 3 113803 C123
# 4 373450 nan
# 5 330877 nan
# 6 17463 E46
# 7 349909 nan
# 8 347742 nan
# 9 237736 nan
# 10 PP 9549 G6
# 11 113783 C103
# 12 A/5. 2151 nan
# 13 347082 nan
# 14 350406 nan
# 15 248706 nan
# 16 382652 nan
# 17 244373 nan
# 18 345763 nan
# 19 2649 nan
# 20 239865 nan
# 21 248698 D56
# 22 330923 nan
# 23 113788 A6
# 24 349909 nan
# 25 347077 nan
# 26 2631 nan
# 27 19950 C23 C25 C27
# 28 330959 nan
# 29 349216 nan
# 30 PC 17601 nan
# 31 PC 17569 B78
# 32 335677 nan
# 33 C.A. 24579 nan
# 34 PC 17604 nan
# 35 113789 nan
# 36 2677 nan
# 37 A./5. 2152 nan
# 38 345764 nan
# 39 2651 nan
# 40 7546 nan
# 41 11668 nan
# 42 349253 nan
# 43 SC/Paris 2123 nan
# 44 330958 nan
# 45 S.C./A.4. 23567 nan
# 46 370371 nan
# 47 14311 nan
# 48 2662 nan
# 49 349237 nan
# 50 3101295 nan
# 51 A/4. 39886 nan
# 52 PC 17572 D33
# 53 2926 nan
# 54 113509 B30
# 55 19947 C52
# 56 C.A. 31026 nan
# 57 2697 nan
# 58 C.A. 34651 nan
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Selecting Numeric Columns
import numpy as np
titanic.select_dtypes(include=[np.number]).dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object

# %%
#where we should use [] and where not? 
#Why don't we use describe(include='something')

#Shows only numeric columns
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Show all columns including non-numeric
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
#Shows only object and float data types columns
titanic.describe(include=['object','float64'])
# Out:
#                            Name   Sex         Age  Ticket        Fare  \
# count                       891   891  714.000000     891  891.000000
# unique                      891     2         NaN     681         NaN
# top     Braund, Mr. Owen Harris  male         NaN  347082         NaN
# freq                          1   577         NaN       7         NaN
# mean                        NaN   NaN   29.699118     NaN   32.204208
# std                         NaN   NaN   14.526497     NaN   49.693429
# min                         NaN   NaN    0.420000     NaN    0.000000
# 25%                         NaN   NaN   20.125000     NaN    7.910400
# 50%                         NaN   NaN   28.000000     NaN   14.454200
# 75%                         NaN   NaN   38.000000     NaN   31.000000
# max                         NaN   NaN   80.000000     NaN  512.329200
#
#           Cabin Embarked
# count       204      889
# unique      147        3
# top     B96 B98        S
# ...

# %%
#Shows only object
titanic.describe(include=['object'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic.drop('Embarked',axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin
# 0      0         A/5 21171   7.2500   NaN
# 1      0          PC 17599  71.2833   C85
# 2      0  STON/O2. 3101282   7.9250   NaN
# 3      0            113803  53.1000  C123
# 4      0            373450   8.0500   NaN

# %%
titanic.drop(2,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.mean(axis=0)
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_4576/187229115.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis=0)
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic.mean(axis=1)
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_4576/2164904919.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis=1)
# 0        4.892857
# 1       16.326186
# 2        5.846429
# 3       13.585714
# 4        7.292857
#           ...
# 886    132.714286
# 887    134.142857
# 888    153.075000
# 889    135.428571
# 890    133.392857
# Length: 891, dtype: float64

# %%
titanic.mean(axis='index')
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_4576/2039727141.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis='index')
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic.mean(axis='columns')
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_4576/2931205895.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis='columns')
# 0        4.892857
# 1       16.326186
# 2        5.846429
# 3       13.585714
# 4        7.292857
#           ...
# 886    132.714286
# 887    134.142857
# 888    153.075000
# 889    135.428571
# 890    133.392857
# Length: 891, dtype: float64

# %%
titanic.drop(2,axis=0).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 3      0     113803  53.1000  C123        S
# 4      0     373450   8.0500   NaN        S
# 5      0     330877   8.4583   NaN        Q

# %%
titanic.mean()
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_11968/929819788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean()
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic.mean(axis=1)
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_11968/2164904919.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis=1)
# 0        4.892857
# 1       16.326186
# 2        5.846429
# 3       13.585714
# 4        7.292857
#           ...
# 886    132.714286
# 887    134.142857
# 888    153.075000
# 889    135.428571
# 890    133.392857
# Length: 891, dtype: float64

# %%
titanic.mean(axis='columns')
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_11968/2931205895.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis='columns')
# 0        4.892857
# 1       16.326186
# 2        5.846429
# 3       13.585714
# 4        7.292857
#           ...
# 886    132.714286
# 887    134.142857
# 888    153.075000
# 889    135.428571
# 890    133.392857
# Length: 891, dtype: float64

# %%
titanic.mean(axis='index')
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_11968/2039727141.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   titanic.mean(axis='index')
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
titanic.Name.str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
titanic[titanic.Name.str.contains('John')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 8              9         1       3
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 172          173         1       3
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 302          303         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# ...

# %%
titanic.Name.str.replace('(','').replace(')','')
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_11968/2872465151.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   titanic.Name.str.replace('(','').replace(')','')
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley Florence Briggs Tha...
# 2                                 Heikkinen, Miss. Laina
# 3            Futrelle, Mrs. Jacques Heath Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic.Name.str.replace('(\(\))', '')
# Out:
# C:\Users\14697\AppData\Local\Temp/ipykernel_11968/4090976381.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   titanic.Name.str.replace('(\(\))', '')
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic['Parch'] = titanic.Parch.astype(float)

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic = pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/main/doc/data/titanic.csv",dtype={'Parch':float})

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.Name.str.contains('john').astype(int).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Name, dtype: int32

# %%
titanic.Parch.mean()
# Out:
# 0.38159371492704824

# %%
titanic.groupby('Embarked').Parch.agg(['count','min','max','mean'])
# Out:
#           count  min  max      mean
# Embarked
# C           168  0.0  3.0  0.363095
# Q            77  0.0  5.0  0.168831
# S           644  0.0  6.0  0.413043

# %%
titanic[titanic.Embarked=='S'].Parch.mean()
# Out:
# 0.41304347826086957

# %%
titanic.groupby('Embarked').mean()
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          445.357143  0.553571  1.886905  30.814769  0.386905  0.363095
# Q          417.896104  0.389610  2.909091  28.089286  0.428571  0.168831
# S          449.527950  0.336957  2.350932  29.445397  0.571429  0.413043
#
#                Fare
# Embarked
# C         59.954144
# Q         13.276030
# S         27.079812

# %%
# %matplotlib inline

# %%
titanic.groupby('Embarked').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Embarked'>

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch          float64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.Ticket.describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
titanic.Ticket.value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %%
titanic.Ticket.value_counts(normalize=True)
# Out:
# 347082      0.007856
# CA. 2343    0.007856
# 1601        0.007856
# 3101295     0.006734
# CA 2144     0.006734
#               ...
# 9234        0.001122
# 19988       0.001122
# 2693        0.001122
# PC 17612    0.001122
# 370376      0.001122
# Name: Ticket, Length: 681, dtype: float64

# %%
titanic.Ticket.unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
titanic.Ticket.nunique()
# Out:
# 681

# %%
pd.crosstab(titanic.Ticket,titanic.Embarked)
# Out:
# Embarked     C  Q  S
# Ticket
# 110152       0  0  3
# 110413       0  0  3
# 110465       0  0  2
# 110564       0  0  1
# 110813       1  0  0
# ...         .. .. ..
# W./C. 6608   0  0  4
# W./C. 6609   0  0  1
# W.E.P. 5734  0  0  1
# W/C 14208    0  0  1
# WE/P 5735    0  0  2
#
# [680 rows x 3 columns]

# %%
titanic.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
titanic.Fare.mean()
# Out:
# 32.2042079685746

# %%
titanic.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %%
# %matplotlib inline

# %%
titanic.Fare.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
titanic.Fare.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.isnull().tail()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False

# %%
titanic.notnull().tail()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 886  True  False      True
# 887  True   True      True
# 888  True  False      True
# 889  True   True      True
# 890  True  False      True

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic[titanic.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dropna(how='any').shape
# Out:
# (183, 12)

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.dropna(how='all').shape
# Out:
# (891, 12)

# %%
titanic.dropna(subset=['Cabin','Embarked'],how='any').shape
# Out:
# (202, 12)

# %%
titanic.dropna(subset=['Cabin','Embarked'],how='all').shape
# Out:
# (891, 12)

# %%
titanic['Embarked'].value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
titanic['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic['Cabin'].fillna(value='B42',inplace=True)

# %%
titanic['Cabin'].value_counts(dropna=False)
# Out:
# B42            688
# G6               4
# C23 C25 C27      4
# B96 B98          4
# F2               3
#               ...
# C91              1
# C32              1
# E34              1
# C7               1
# C148             1
# Name: Cabin, Length: 147, dtype: int64

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic[titanic.Embarked=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
titanic.loc[6,'Name']
# Out:
# 'McCarthy, Mr. Timothy J'

# %%
titanic.set_index('Name',inplace=True)

# %%
titanic.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
titanic.index
# Out:
# Index(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        ...
#        'Markun, Mr. Johann', 'Dahlberg, Miss. Gerda Ulrika',
#        'Banfield, Mr. Frederick James', 'Sutehall, Mr. Henry Jr',
#        'Rice, Mrs. William (Margaret Norton)', 'Montvila, Rev. Juozas',
#        'Graham, Miss. Margaret Edith',
#        'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell',
#        'Dooley, Mr. Patrick'],
#       dtype='object', name='Name', length=891)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.shape
# Out:
# (891, 11)

# %%
titanic.loc['McCarthy, Mr. Timothy J','Embarked']
# Out:
# 'S'

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe().index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
titanic.describe().columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
titanic.describe().loc['25%','Pclass']
# Out:
# 2.0

# %%
titanic.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
titanic.set_index('Name',inplace=True)

# %%
titanic.head()
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
#
#                                                     Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                                  3    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
titanic.Embarked.head()
# Out:
# Name
# Braund, Mr. Owen Harris                                S
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)    C
# Heikkinen, Miss. Laina                                 S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           S
# Allen, Mr. William Henry                               S
# Name: Embarked, dtype: object

# %%
titanic.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic.Embarked.value_counts().index
# Out:
# Index(['S', 'C', 'Q'], dtype='object')

# %%
titanic.Embarked.value_counts().values
# Out:
# array([644, 168,  77], dtype=int64)

# %%
titanic.Embarked.value_counts()['S']
# Out:
# 644

# %%
titanic.Embarked.value_counts().sort_value()
# Out:
# Q     77
# C    168
# S    644
# Name: Embarked, dtype: int64

# %%
titanic.Embarked.value_counts().sort_index()
# Out:
# C    168
# Q     77
# S    644
# Name: Embarked, dtype: int64

# %%
passenger_details = pd.Series([3000000,85000],index=['Albania','Andorra'],name='country')

# %%
passenger_details
# Out:
# Albania    3000000
# Andorra      85000
# Name: country, dtype: int64

# %%
titanic.Fare * passenger_details
# Out:
# Abbing, Mr. Anthony                     NaN
# Abbott, Mr. Rossmore Edward             NaN
# Abbott, Mrs. Stanton (Rosa Hunt)        NaN
# Abelson, Mr. Samuel                     NaN
# Abelson, Mrs. Samuel (Hannah Wizosky)   NaN
#                                          ..
# de Mulder, Mr. Theodore                 NaN
# de Pelsmaeker, Mr. Alfons               NaN
# del Carlo, Mr. Sebastiano               NaN
# van Billiard, Mr. Austin Blyler         NaN
# van Melkebeke, Mr. Philemon             NaN
# Length: 893, dtype: float64

# %%
pd.concat([titanic,passenger_details],axis=1).head()
# Out:
#                                                     PassengerId  Survived  \
# Braund, Mr. Owen Harris                                     1.0       0.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...          2.0       1.0
# Heikkinen, Miss. Laina                                      3.0       1.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                4.0       1.0
# Allen, Mr. William Henry                                    5.0       0.0
#
#                                                     Pclass     Sex   Age  \
# Braund, Mr. Owen Harris                                3.0    male  22.0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...     1.0  female  38.0
# Heikkinen, Miss. Laina                                 3.0  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)           1.0  female  35.0
# Allen, Mr. William Henry                               3.0    male  35.0
#
#                                                     SibSp  Parch  \
# ...

# %%
titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.loc[0,:]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
titanic.loc[[0,1,2],:]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.loc[0:2,:]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic.loc[:,['Ticket','Age']]
# Out:
#                Ticket   Age
# 0           A/5 21171  22.0
# 1            PC 17599  38.0
# 2    STON/O2. 3101282  26.0
# 3              113803  35.0
# 4              373450  35.0
# ..                ...   ...
# 886            211536  27.0
# 887            112053  19.0
# 888        W./C. 6607   NaN
# 889            111369  26.0
# 890            370376  32.0
#
# [891 rows x 2 columns]

# %%
titanic.loc[titanic.Embarked=='S']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
titanic.iloc[:,[0,3]]
# Out:
#      PassengerId                                               Name
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
titanic.iloc[:,0:4]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# ...

# %%
titanic.iloc[0:3,:]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
titanic[['Ticket','Fare']]
# Out:
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
# [891 rows x 2 columns]

# %%
titanic.drop('Cabin',axis=1).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.drop('Cabin',axis=1,inplace=True)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
titanic.dropna(how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic = titanic.set_index('Time')
